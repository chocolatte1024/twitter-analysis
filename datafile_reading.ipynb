# %%
import json

# Open the JSON file
with open('twitter-@onedirection') as f:
    # Load the JSON data
    for line in f:
        # Load the JSON data from each line
        data = json.loads(line)

        # Access the data in the JSON object
        print(data)
        print()
# Out:
# {'_type': 'snscrape.modules.twitter.Tweet', 'url': 'https://twitter.com/onedirection/status/1288519659470426112', 'date': '2020-07-29T17:00:01+00:00', 'rawContent': 'So many memories ❤️ Thanks for celebrating with us! Directioners forever #10YearsOf1D https://t.co/mW0atB9cOG', 'renderedContent': 'So many memories ❤️ Thanks for celebrating with us! Directioners forever #10YearsOf1D https://t.co/mW0atB9cOG', 'id': 1288519659470426112, 'user': {'_type': 'snscrape.modules.twitter.User', 'username': 'onedirection', 'id': 209708391, 'displayname': 'One Direction', 'rawDescription': '#10YearsOf1D Listen to your favourite 1D songs here… https://t.co/Van2RFMJ1c', 'renderedDescription': '#10YearsOf1D Listen to your favourite 1D songs here… 1d.lnk.to/10YearsOf1DPla…', 'descriptionLinks': [{'_type': 'snscrape.modules.twitter.TextLink', 'text': '1d.lnk.to/10YearsOf1DPla…', 'url': 'https://1d.lnk.to/10YearsOf1DPlaylists', 'tcourl': 'https://t.co/Van2RFMJ1c', 'indices': [53, 76]}], 'verified': Fals
# ...
